# %% [markdown]
# # 02 — Preprocessing
#
# **Purpose:** Clean and transform the raw dataset into an analysis-ready form, based only on data quality issues confirmed in `01_data_understanding.ipynb`.
#
# **Input:** Raw data (`data/raw/`) + findings from notebook 01.
#
# **Processing:** Missing-value handling, duplicate removal, state/category normalization, type conversion, feature engineering — only the steps actually justified by observed issues.
#
# **Output:** Clean dataset saved to `data/processed/`.
#
# **Depends on:** Dataset Validation Gate being completed in notebook 01.
#
# **Status: placeholder — do not run until notebook 01 is complete.**

# %% [markdown]
# ## 1. Load raw data

# %%
import sys
sys.path.append('..')

from src.data_loader import load_raw_dataset
from src.preprocessing import check_missing_values, check_duplicates

# df = load_raw_dataset(...)  # TODO: fill in once implemented

# %% [markdown]
# ## 2. Apply only justified transformations
#
# For each transformation below, state which quality issue (from notebook 01) it addresses. Do not add a transformation without a documented reason.

# %% [markdown]
# ### 2.1 Missing values
# TODO — reference notebook 01 findings.

# %% [markdown]
# ### 2.2 Duplicates
# TODO — reference notebook 01 findings.

# %% [markdown]
# ### 2.3 State/UT name normalization
# TODO — only if inconsistent naming was actually observed.

# %% [markdown]
# ### 2.4 Crime category normalization
# TODO — only if inconsistent naming was actually observed.

# %% [markdown]
# ### 2.5 Type conversion / feature engineering
# TODO — only if needed for downstream stages.

# %% [markdown]
# ## 3. Save processed dataset
#
# Save to `data/processed/` using `src.preprocessing.save_processed_dataset`. Never overwrite files in `data/raw/`.

# %% [markdown]
# ## 4. Summary of changes
#
# TODO — document exactly what was changed and why, for reproducibility and viva explanation.
