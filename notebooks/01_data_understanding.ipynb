# %% [markdown]
# # 01 — Data Understanding
#
# **Purpose:** Inspect the real, supplied dataset before any cleaning or modeling. This notebook implements the **Dataset Validation Gate** described in `PROJECT_PLAN.md`.
#
# **Input:** Raw file(s) in `data/raw/` (not yet supplied).
#
# **Processing:** Load, inspect structure, characterize quality, and answer the per-technique validation questions.
#
# **Output:** A data dictionary, initial observations, and a completed Dataset Validation Gate summary (to be copied back into `PROJECT_PLAN.md`).
#
# **Status: placeholder — dataset not yet supplied. Do not run analysis cells below with fabricated data.**

# %% [markdown]
# ## 1. Load raw data
#
# List files present in `data/raw/` and load the dataset using `src.data_loader`.

# %%
import sys
sys.path.append('..')

from src.data_loader import list_raw_files

list_raw_files()  # TODO: confirm real filename(s) before loading

# %% [markdown]
# ## 2. Basic structure
#
# TODO once data is loaded:
# - Row count, column count
# - Column names and dtypes (`df.info()`)
# - First/last few rows (`df.head()`, `df.tail()`)

# %% [markdown]
# ## 3. Coverage
#
# TODO:
# - Time coverage (min/max year, gaps)
# - Geographic coverage (distinct states/UTs, any missing regions)
# - Crime-category coverage (distinct categories, granularity)

# %% [markdown]
# ## 4. Data quality
#
# TODO — use `src.preprocessing.check_missing_values` and `check_duplicates`:
# - Missing values per column
# - Duplicate records
# - Inconsistent naming (states, categories)
# - Whether multiple files require integration

# %% [markdown]
# ## 5. Dataset Validation Gate — per-technique assessment
#
# Answer each question directly from what was observed above. Do not guess.
#
# | Technique | Supported? | Evidence / Reasoning |
# |---|---|---|
# | Classification | TBD | TBD |
# | Regression / Forecasting | TBD | TBD |
# | Apriori | TBD | TBD |
# | K-Means Clustering | TBD | TBD |
# | Outlier Detection | TBD | TBD |
#
# **Decision:** Copy this completed table into `PROJECT_PLAN.md` before proceeding to `02_preprocessing.ipynb`.

# %% [markdown]
# ## 6. Findings summary
#
# TODO — 3-6 bullet points summarizing what was learned about the dataset, written only after the sections above are complete.
